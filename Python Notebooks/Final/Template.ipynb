# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
data = pd.read_csv('/Users/amr/Documents/GitHub/NMI-Placement-2024/Data/InterpolatedL 588_2024-08-15 16-23 - BSA (37 C) 2gL 50uL (LC - A-RC 10 kDa-Water) Vcf100 Vx400g Vf400.csv')
time = data['time (min)']
signal_intensity = data['raw light scattering data: detector voltage  (V) detector 11']
absorbance_UV1 = data['UV absorbance data: absorbance  (AU) channel 1']
absorbance_UV2 = data['UV absorbance data: absorbance  (AU) channel 2']

# %%
import importlib
import despiking
importlib.reload(despiking)
from despiking import *

# %%
plot_despiked_data(time,signal_intensity,5)
print(despiked_signal_intensity(signal_intensity,kernel_size=5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 plot_despiked_data(time,signal_intensity,5)
# ----> 2 print(despiked_signal_intensity(signal_intensity,kernel_size=5))
#
# NameError: name 'despiked_signal_intensity' is not defined
