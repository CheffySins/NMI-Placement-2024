# %% [markdown]
# # Week 1 - 02 AUG '24
# Introduction to the two different projects. I have chosen to go with the FFF option.
#
# ## Flow Field Flow Fractionation (FFFF)
# - What is it?
# - What are some good references?
# - Notes on it?

# %%
# Only need to run this the first time
# !pip install pandas

# %%
import pandas as pd
import numpy as np

rawData = 'InstLayout 588_2024-08-15 16-23 - BSA (37 C) 2gL 50uL (LC - A-RC 10 kDa-Water) Vcf100 Vx400g Vf400.csv'
df = pd.read_csv(rawData)

# %%
df.head()
# Out:
#    time (min)  raw light scattering data: detector voltage  (V) detector 2  \
# 0    0.001600                                           0.083025
# 1    0.010133                                           0.083008
# 2    0.018667                                           0.082991
# 3    0.027200                                           0.082977
# 4    0.035733                                           0.082967
#
#    raw light scattering data: detector voltage  (V) detector 3  \
# 0                                           0.027269
# 1                                           0.027273
# 2                                           0.027283
# 3                                           0.027286
# 4                                           0.027287
#
#    raw light scattering data: detector voltage  (V) detector 4  \
# 0                                           0.012823
# 1                                           0.012820
# 2                                           0.012826
# ...
